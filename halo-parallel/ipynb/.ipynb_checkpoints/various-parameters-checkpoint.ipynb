# %%
import sys
import glob
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
plt.style.use('seaborn-poster')
lines = ["-","--","-.",":", "o", "v", "d", "^", "<", ">", "1", "2", "3", "4", "s", "p", "*"]

# %%
## Show off all the files
glob.glob('../gxx/neutrino-headon/range1/*.csv')
# Out:
# ['../gxx/neutrino-headon/range1/neutrino-headon_MU_5.000000_REFL0.200000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-30-35.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_5.000000_REFL0.100000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-25-10.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_5.000000_REFL0.200000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-41-37.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_10.000000_REFL0.300000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-37-43.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_10.000000_REFL0.100000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-27-27.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_1.000000_REFL0.010000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-24-51.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_1.000000_REFL0.100000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-35-31.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_0.500000_REFL0.100000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-24-32.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_0.100000_REFL0.300000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-43-39.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_0.100000_REFL0.200000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-29-46.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_10.000000_REFL0.100000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-38-48.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_10.000000_REFL0.200000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-31-56.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_20.000000_REFL0.200000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-33-14.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_0.500000_REFL0.100000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-35-12.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_0.100000_REFL0.050000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-29-55.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_20.000000_REFL0.010000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-28-48.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_20.000000_REFL0.200000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-42-58.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_0.500000_REFL0.200000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-30-1.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_0.500000_REFL0.300000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-43-54.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_0.100000_REFL0.100000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-23-56.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_0.500000_REFL0.050000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-30-9.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_20.000000_REFL0.050000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-33-28.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_20.000000_REFL0.100000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-28-55.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_0.100000_REFL0.200000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-40-52.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_5.000000_REFL0.010000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-25-5.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_10.000000_REFL0.050000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-32-23.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_10.000000_REFL0.200000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-42-15.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_5.000000_REFL0.300000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-44-34.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_0.100000_REFL0.010000_ITER1000000_STEPS10000_RANGE1.000000_TH_4_t2017-11-9-19-28-5.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_20.000000_REFL0.300000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-46-8.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_0.100000_REFL0.100000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-34-56.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_1.000000_REFL0.050000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-30-32.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_0.500000_REFL0.300000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-35-3.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_1.000000_REFL0.300000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-44-17.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_5.000000_REFL0.100000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-35-53.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_10.000000_REFL0.010000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-25-40.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_5.000000_REFL0.050000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-31-44.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_0.100000_REFL0.010000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-24-1.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_20.000000_REFL0.300000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-39-36.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_0.500000_REFL0.010000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-24-33.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_10.000000_REFL0.300000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-45-26.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_5.000000_REFL0.300000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-35-40.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_0.500000_REFL0.200000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-41-6.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_20.000000_REFL0.100000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-39-50.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_0.100000_REFL0.300000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-34-46.csv',
#  '../gxx/neutrino-headon/range1/neutrino-headon_MU_1.000000_REFL0.200000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-41-21.csv']

# %%
# os.listdir("../scripts/refl/")
# csvlist = glob.glob('../scripts/refl/*_REFL0.0*RANGE20*.csv')
mu5_csvlist = glob.glob('../gxx/neutrino-headon/range1/*MU_5.0*.csv')
csvlist = np.sort(mu5_csvlist)
csvlist
# Out:
# array([ '../gxx/neutrino-headon/range1/neutrino-headon_MU_5.000000_REFL0.010000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-25-5.csv',
#        '../gxx/neutrino-headon/range1/neutrino-headon_MU_5.000000_REFL0.050000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-31-44.csv',
#        '../gxx/neutrino-headon/range1/neutrino-headon_MU_5.000000_REFL0.100000_ITER100000_STEPS1000_RANGE1.000000_TH_4_t2017-11-9-19-35-53.csv',
#        '../gxx/neutrino-headon/range1/neutrino-headon_MU_5.000000_REFL0.200000_ITER1000000_STEPS1000_RANGE1.000000_TH_20_t2017-11-10-13-3-9.csv',
#        '../gxx/neutrino-headon/range1/neutrino-headon_MU_5.000000_REFL0.300000_ITER1000000_STEPS1000_RANGE1.000000_TH_20_t2017-11-10-13-4-32.csv'],
#       dtype='<U136')

# %%
def dataimp(path):
    
#     return np.genfromtxt("../scripts/refl/" + path, delimiter = ", ")
    return np.genfromtxt( path, delimiter = ", ")

# %%
datarr = []

for i in range(len(csvlist)):
    
    datarr.append( dataimp(csvlist[i]) )

print("Data Loaded")
# Out:
# Data Loaded

# %%
totlen = len(datarr[0])
length = int(len(datarr[0][0])/2)

x = datarr[0][0][:length+1]
tott = int( (totlen-1)/3 )

# %%
def plotdata(dataraw, style, id):
    
    datafull = dataraw
    datafull = np.delete(datafull,0, axis=0)
    data = datafull[::3]
    data = np.insert(data, 0 ,dataraw[0], axis=0)
    
    plt.plot(x, data[-1][:length+1]/2+0.5, lines[style]+"r", linewidth=2, markersize = 6, label='R='+id+' Forward')
    plt.plot(x, data[-1][length:2*length+1][::-1]/2+0.5, lines[style]+'k', linewidth=2, markersize = 6, label='R='+id+' Backward')

def logplotdata(dataraw, style, id):

    datafull = dataraw
    datafull = np.delete(datafull,0, axis=0)
    data = datafull[::3]
    data = np.insert(data, 0 ,dataraw[0], axis=0)
    
    plt.semilogy(x, data[-1][:length+1]/2+0.5, lines[style]+"r", linewidth=2, markersize = 6, label='R='+id+' Forward')
    plt.semilogy(x, data[-1][length:2*length+1][::-1]/2+0.5, lines[style]+'k', linewidth=2, markersize = 6, label='R='+id+' Forward')

# %%
s2thetav = 0.916515138991;
omegav = 1;

def ProbTh(x):
    
    return 1 - ( s2thetav**2 )* np.sin( omegav * x / 2 )**2

lengthth = 100;
xth = np.arange(0,20,10/lengthth)
# print(x)
ptheory = ProbTh(xth)

# %%
def implt(data, asratio, pltitle):
    plttemp = plt.imshow(data, cmap='viridis', interpolation='nearest', aspect=asratio, vmin=0, vmax =1.0, origin='lower')
    axtemp = plt.gca()
    axtemp.tick_params(right='on')
    plt.axvline(x=100, ymin=0, ymax = 1, linewidth=1, color='gray')
    plt.title(pltitle)
    plt.colorbar(plttemp)

# %% [markdown]
# ## IM Plots

# %%
dz = -datarr[0][0][0] + datarr[0][0][1];
dt = 1;
z, t = np.mgrid[0:10+dz:dz, 0:tott:1]

bp = 1;
edp = -1; # 1000000

def pdata(i,begin, end):
    return [datarr[i][begin:end:3]/2 + 0.5, csvlist[i][46:-34], datarr[i][0]]


p0 = pdata(0,bp,edp)
p1 = pdata(1,bp,edp)


# ar=1/10
ar= 'auto'

# %%
for i in np.arange(len(csvlist)):
    
    ptemp = pdata(i,bp,edp)
    implt( ptemp[0], ar, '$\mu=5$\n' + ptemp[1] )
    plt.show()

# %%
datacomp=dataimp('../gxx/neutrino-headon-incline/neutrino-headon-incline-0.00_MU_5.000000_REFL0.200000_ITER100000_STEPS1000_RANGE1.000000_TH_20_t2017-11-10-18-47-45.csv')

# %%
pcomp = [datacomp[bp:edp:3]/2 + 0.5, 'Comp', datacomp[0]]
implt( pcomp[0], ar, '$\mu=5$\n' + pcomp[1] )
plt.show()

# %% [markdown]
# ## Specific z

# %%
for i in np.arange(len(csvlist)):

    ptemp = pdata(i,1,-1)
    
    zlocationtemp = 51;

    plt.plot( ptemp[0][:,zlocationtemp], label=ptemp[1])
    plt.ylim([0,1.05])
    plt.title('At location z='+str(zlocationtemp))
    
    plt.legend()
    plt.show()

# %% [markdown]
# ## Equilibrium

# %%
for i in np.arange(len(csvlist)):

    ptemp = pdata(i,1,-1)

    plt.plot( ptemp[2], ptemp[0][-1], label=ptemp[1])
    plt.ylim([0,1])

    
plt.legend()
plt.axvline(x=1, ymin=0, ymax = 1, linewidth=1, color='gray')
plt.title('Survival Probability for $\mu=0.1\omega_v$')
plt.xlabel('$z/\omega_v$')
plt.ylabel('Survival Probability')
plt.show()
