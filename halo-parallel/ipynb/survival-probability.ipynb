# %%
import sys
import glob
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
plt.style.use('seaborn-poster')
lines = ["-","--","-.",":", "o", "v", "d", "^", "<", ">", "1", "2", "3", "4", "s", "p", "*"]

# %%
# os.listdir("../scripts/refl/")
# csvlist = glob.glob('../scripts/refl/*_REFL0.0*RANGE20*.csv')
# csvlist = glob.glob('../gxx/neutrino-headon-avg/varyalpha-bahcall/*.csv')
csvlist = glob.glob('../gxx/neutrino-headon-evo/*.csv')
csvlist
# Out:
# ['../gxx/neutrino-headon-evo/neutrino-headon-evo_MU_1.000000_REFL0.000000_ITER150000_STEPS5000_RANGE5.000000_TH_22_t2017-11-17-20-58-13.csv',
#  '../gxx/neutrino-headon-evo/neutrino-headon-evo_MU_5.000000_REFL0.200000_ITER300000_STEPS10000_RANGE5.000000_TH_22_t2017-11-20-14-25-4.csv',
#  '../gxx/neutrino-headon-evo/neutrino-headon_MU_1.000000_REFL0.000000_ITER1500000_STEPS50000_RANGE5.000000_TH_22_t2017-11-17-22-46-34.csv',
#  '../gxx/neutrino-headon-evo/neutrino-headon_MU_5.000000_REFL0.100000_ITER1500000_STEPS50000_RANGE5.000000_TH_22_t2017-11-18-6-32-20.csv',
#  '../gxx/neutrino-headon-evo/neutrino-headon-evo_MU_5.000000_REFL0.000000_ITER150000_STEPS5000_RANGE5.000000_TH_22_t2017-11-17-20-59-41.csv',
#  '../gxx/neutrino-headon-evo/neutrino-headon_MU_1.000000_REFL0.100000_ITER150000_STEPS5000_RANGE5.000000_TH_22_t2017-11-17-21-2-18.csv',
#  '../gxx/neutrino-headon-evo/neutrino-headon-evo_MU_1.000000_REFL0.100000_ITER1500000_STEPS50000_RANGE5.000000_TH_22_t2017-11-18-2-10-42.csv',
# ...

# %%
data = np.genfromtxt('../gxx/neutrino-headon-evo/neutrino-headon-evo_MU_5.000000_REFL0.200000_ITER1500000_STEPS50000_RANGE5.000000_TH_22_t2017-11-18-10-19-31.csv', delimiter = ", ")
# data = np.genfromtxt('../gxx/neutrino-headon-evo/neutrino-headon_MU_5.000000_REFL0.200000_ITER300000_STEPS10000_RANGE5.000000_TH_22_t2017-11-20-14-32-46.csv', delimiter = ", ")

# %%
totlen = len(data)
length = int(len(data)/2)

x = data[0][:length+1]
tott = int( (totlen-1)/3 )

# %%
data_prob = data[4::3,76]/2+0.5

# %%
data_uni = data[-1]**2 + data[-2]**2 + data[-3]**2

# %%
plt.plot( data_prob )
plt.show()

# %%
plt.plot( data_uni )
plt.show()
